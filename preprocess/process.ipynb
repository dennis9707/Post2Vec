# %%
import pandas as pd

# %%
train = pd.read_csv("../data/tagdc_csv/Posts.csv",encoding = "ISO-8859-1")

# %%
train.head(
)
# Out:
#    Id             CreationDate  \
# 0  14  2008-08-01T00:59:11.177
# 1  11  2008-07-31T23:55:37.967
# 2  13  2008-08-01T00:42:38.903
# 3   9  2008-07-31T23:40:59.743
# 4  16  2008-08-01T04:59:33.643
#
#                                                Title  \
# 0  Difference between Math.Floor() and Math.Trunc...
# 1         How can relative time be calculated in C#?
# 2                        Determine a User's Timezone
# 3            How do I calculate someone's age in C#?
# 4  Filling a DataSet or DataTable from a LINQ que...
#
#                                                 Body  \
# 0  What is the difference between Math.Floor() an...
# 1  Given a specific DateTime value, how do I disp...
# 2  Is there any standard way for a Web Server to ...
# 3  Given a DateTime representing a person's birth...
# 4  How do you expose a LINQ query as an ASMX web ...
#
#                                                 Code  \
# 0                                                NaN
# ...

# %%
train.loc[[50000]]
# Out:
#            Id             CreationDate                            Title  \
# 50000  350603  2008-12-08T19:38:50.450  SVN/Tortoise - Label generation
#
#                                                     Body Code  \
# 50000  In Clearcase I can generate a "label" for a gi...  NaN
#
#                                Tags
# 50000  ['svn', 'change-management']

# %%
sorted = train.sort_values(by='CreationDate') #

# %%
sorted.loc[[11203032]]
# Out:
#                 Id             CreationDate  \
# 11203032  36542023  2016-04-11T07:08:29.287
#
#                                                   Title  \
# 11203032  Get the state of the hdfs namenode using java
#
#                                                        Body  \
# 11203032  I am creating a java application that will rea...
#
#                                                        Code  \
# 11203032  org.apache.hadoop.ipc.RemoteException(org.apac...
#
#                                 Tags
# 11203032  ['java', 'hadoop', 'hdfs']

# %%
sorted.head()
# Out:
#    Id             CreationDate  \
# 5   4  2008-07-31T21:42:52.667
# 6   6  2008-07-31T22:08:08.620
# 3   9  2008-07-31T23:40:59.743
# 1  11  2008-07-31T23:55:37.967
# 2  13  2008-08-01T00:42:38.903
#
#                                                Title  \
# 5  When setting a form's opacity should I use a d...
# 6  Percentage width child element in absolutely p...
# 3            How do I calculate someone's age in C#?
# 1         How can relative time be calculated in C#?
# 2                        Determine a User's Timezone
#
#                                                 Body  \
# 5  I want to use a track-bar to change a form's o...
# 6  I have an absolutely positioned div containing...
# 3  Given a DateTime representing a person's birth...
# 1  Given a specific DateTime value, how do I disp...
# 2  Is there any standard way for a Web Server to ...
#
#                                                 Code  \
# 5  decimal trans = trackBar1.Value / 5000; this.O...
# ...

# %%
final = sorted[(sorted['CreationDate']< '2014-07-01')]

# %%
final.tail()
# Out:
#                Id             CreationDate  \
# 7199273  24500648  2014-06-30T23:59:18.737
# 7199275  24500649  2014-06-30T23:59:19.937
# 7199285  24500650  2014-06-30T23:59:26.080
# 7199270  24500651  2014-06-30T23:59:27.233
# 7199281  24500653  2014-06-30T23:59:52.843
#
#                                                      Title  \
# 7199273                       Limit method parameter value
# 7199275           How to get All Text in robot framework ?
# 7199285  Cannot connect to remote mongo database on Lin...
# 7199270           How to get current Buddypress page name?
# 7199281    update matched records from another collection?
#
#                                                       Body  \
# 7199273  I'm building a library, and some of my methods...
# 7199275  Consider the following source code, How do i r...
# 7199285  I know there are very similar questions, but I...
# 7199270  I am trying to dynamically display the name of...
# ...

# %%
sorted.loc[[7199282]]
# Out:
#                Id             CreationDate  \
# 7199282  24500665  2014-07-01T00:02:02.217
#
#                                                      Title  \
# 7199282  Getting a mysql thread id from sqlalchemy Session
#
#                                                       Body Code  \
# 7199282  I'm used to creating connections using MySQLdb...  NaN
#
#                                                       Tags
# 7199282  ['python', 'mysql', 'sqlalchemy', 'mysql-python']
