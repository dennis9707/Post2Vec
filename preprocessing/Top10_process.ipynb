# %%
import pandas
df = pandas.read_pickle('../data/questions/Questions54Top10.pkl')

# %%
df.head()
# Out:
#         qid                                              title  \
# 0  67881547          Formating a sum reduce function in Python
# 1  67881569  Functionallity (supposedly) of shutil.which("f...
# 2  67881560  How to create a Telegram Bot Inline Keyboard M...
# 3  67881549         app.use() and router.post() is not working
# 4  67881553    Remove an object inside an array based on value
#
#                                            desc_text  \
# 0  I'm trying to format the result of a sum funct...
# 1  I have a github project for my app Scout. I us...
# 2  I have created a Python Telegram Bot with an I...
# 3  My app.use() is not working.It shows 'Cannot P...
# 4  I would like to ask how to remove an element i...
#
#                                            desc_code            creation_date  \
# 0  from functools import reduce def sum_equation(...  2021-06-08T04:46:55.547
# 1                                                NaN  2021-06-08T04:49:10.447
# ...

# %%
df.tail()
# Out:
#              qid                                              title  \
# 221043  69060955  How to prevent arithmetic overflow from corrup...
# 221044  69061016  How to add AI recommendation feature in to and...
# 221045  69061013          How do I make input range display number?
# 221046  69061026         how to accept when MultipartFile is empty?
# 221047  69061027  crawl website that uses php session and change...
#
#                                                 desc_text  \
# 221043  I have a class that has two int fields x and y...
# 221044  can I know how can I add AI recommendation fea...
# 221045  I want this slider to display the number. At t...
# 221046  For the below code when I am trying to hit thr...
# 221047  I want to crawl the following page: https://db...
#
#                                                 desc_code  \
# 221043  class MyClass { private int x; private int y; ...
# 221044                                                NaN
# ...

# %%
train_size = 0.7
train_dataset = df.sample(frac=train_size, random_state=200)
test_dataset = df.drop(train_dataset.index).reset_index(drop=True)
train_dataset = train_dataset.reset_index(drop=True)


valid_dataset = test_dataset.sample(frac=0.5, random_state=42)
test_dataset = test_dataset.drop(valid_dataset.index).reset_index(drop=True)
valid_dataset = valid_dataset.reset_index(drop=True)

print("FULL Dataset: {}".format(df.shape))
print("TRAIN Dataset: {}".format(train_dataset.shape))
print("TEST Dataset: {}".format(test_dataset.shape))
print("VALID Dataset: {}".format(valid_dataset.shape))

train_dataset.to_csv("../data/questions/Train_Questions54.csv", index=False)
valid_dataset.to_csv("../data/questions/Valid_Questions54.csv", index=False)
test_dataset.to_csv("../data/questions/Test_Questions54.csv", index=False)
# Out:
# FULL Dataset: (221048, 6)
# TRAIN Dataset: (154734, 6)
# TEST Dataset: (33157, 6)
# VALID Dataset: (33157, 6)

# %%
train_dataset.to_pickle("../data/questions/Train_Questions54Top10.pkl")
valid_dataset.to_pickle("../data/questions/Valid_Questions54Top10.pkl")
test_dataset.to_pickle("../data/questions/Test_Questions54Top10.pkl")

# %%
df_train = pandas.read_pickle("../data/questions/Train_Questions54Top10.pkl")
# valid_dataset.to_pickle("../data/questions/Valid_Questions54Top10.pkl")
# test_dataset.to_pickle("../data/questions/Test_Questions54Top10.pkl")

# %%
df_train.head()
# Out:
#         qid                                              title  \
# 0  68945060      React make useState initial value conditional
# 1  68111792  Elevate application to administration by limit...
# 2  68303073  Nested Router in ReactJS - Show blank page on ...
# 3  68953821       How to map POCO into Record using AutoMapper
# 4  68758004  Header detail footer report in python like out...
#
#                                            desc_text  \
# 0  I am trying to set initial state based on data...
# 1  Currently i'm busy creating an application for...
# 2  I am a beginner in ReactJS and React Router an...
# 3  I'm using AutoMapper 10.1.1 with .NET 6 (previ...
# 4  I am trying to create a report from my datafra...
#
#                                            desc_code            creation_date  \
# 0  const Calculate({data}) => { const [number, se...  2021-08-26T20:39:33.023
# 1                                                NaN  2021-06-24T08:01:27.023
# ...
